# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\Hp\\Documents\\Ramboll\\DistributionParameters.csv',encoding='latin1', header=None)

# %%
wind_speeds = [4, 6, 8, 10, 12, 14, 16, 18, 20]
max_loads = [16.8629, 19.9231, 13.9205, 18.5178, 322.1104, 391.9641, 1.5543, 2.6895, 2.6757]

plt.plot(wind_speeds, max_loads)
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Max Loads')
plt.title('Max Loads vs Wind Speeds')
plt.show()

# %%
wind_speeds = [4, 6, 8, 10, 12, 14, 16, 18, 20]
max_loads = [16.8629, 19.9231, 13.9205, 18.5178, 322.1104, 391.9641, 1.5543, 2.6895, 2.6757]

plt.scatter(wind_speeds, max_loads)
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Max Loads')
plt.title('Max Loads vs Wind Speeds')
plt.show()

# %%
locations = ['LSSGagMya', 'LSSGagMza', 'YawBrMxp', 'YawBrMyp', 'TwrBsMxt', 'TwrBsMxyt', 'Fair1Ten', 'Fair2Ten', 'Fair3Ten', 'Anch1Ten', 'Anch2Ten', 'Anch3Ten']
max_loads = [16.8629, 19.9231, 13.9205, 18.5178, 322.1104, 391.9641, 1.5543, 2.6895, 2.6757, 1.2919, 2.4285, 2.4147]

plt.bar(locations, max_loads)
plt.xticks(rotation=90)
plt.xlabel('Locations')
plt.ylabel('Max Loads')
plt.title('Max Loads for Different Locations')
plt.show()
